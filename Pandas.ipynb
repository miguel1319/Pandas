# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel1319/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
# SQL for Python pretty much

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive')
df=pd.read_csv('gdrive/My Drive/pokemon_data.csv') # use delimiter to separate by different characters  '''delimiter = '\t' '''

#can also use other bult in functions like
#pd.read_excel() for excel
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Head and tail of table
df.head(2)
df.tail(2)

#print the index for the columns
print(df.columns)

#print specific column
print(df['Name'])
print(df[['Name','Type 1','Legendary']])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
#                       Name   Type 1  Legendary
# 0                Bulbasaur    Grass      False
# 1                  Ivysaur    Grass      False
# 2                 Venusaur    Grass      False
# 3    VenusaurMega Venusaur    Grass      False
# 4               Charmander     Fire      False
# ..                     ...      ...        ...
# 795                Diancie     Rock       True
# 796    DiancieMega Diancie     Rock       True
# ...

# %%
#print using iloc
print(df.iloc[1]) #get index of a row
print(df.iloc[1,1]) #get specific cell
print(df.iloc[1:4])#get multiple columns

#print all columns
for index, rows in df.iterrows():
  print(index, rows['Name'],rows['HP'])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# Ivysaur
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 0 Bulbasaur 45
# 1 Ivysaur 60
# 2 Venusaur 80
# 3 VenusaurMega Venusaur 80
# 4 Charmander 39
# 5 Charmeleon 58
# 6 Charizard 78
# 7 CharizardMega Charizard X 78
# 8 CharizardMega Charizard Y 78
# ...

# %%
#loacte specific values
df.loc[df['Type 1'] == "Fire"]

#gives infromation like mean, std,min,max
df.describe()

#sort values by add parent when wanting to sort by differtent order
df.sort_values(['Name'], ascending=True)
df.sort_values(['Name','HP'], ascending=[0,1])

#create a new df to add a column
#df['Total'] = df['HP'] + df['Attack']
#df = df.drop(columns=['Total'])

#save columns as a list
columns = list(df.columns.values)
print(columns)

df['Total'] = df.iloc[:,4:10].sum(axis=1) #axis = 0 then it will add vertically


df = df[columns[0:4] + [columns[-1]] + columns[4:12]]
df.head()
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    591  45      49
# 1  2                Ivysaur  Grass  Poison      False    750  60      62
# 2  3               Venusaur  Grass  Poison      False    970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False   1170  80     100
# 4  4             Charmander   Fire     NaN      False    553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1
